# %%
#concentrating multiple dataframes and checking for missing values
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
aot = pd.read_csv('datasets/PRSA_Data_Aotizhongxin_20130301-20170228.csv')

# %%
chan = pd.read_csv('datasets/PRSA_Data_Changping_20130301-20170228.csv')

# %%
ding = pd.read_csv('datasets/PRSA_Data_Dingling_20130301-20170228.csv')

# %%
guan = pd.read_csv('datasets/PRSA_Data_Guanyuan_20130301-20170228.csv')

# %%
dong = pd.read_csv('datasets/PRSA_Data_Dongsi_20130301-20170228.csv')

# %%
guch = pd.read_csv('datasets/PRSA_Data_Gucheng_20130301-20170228.csv')

# %%
hua = pd.read_csv('datasets/PRSA_Data_Huairou_20130301-20170228.csv')

# %%
nong = pd.read_csv('datasets/PRSA_Data_Nongzhanguan_20130301-20170228.csv')

# %%
tian = pd.read_csv('datasets/PRSA_Data_Tiantan_20130301-20170228.csv')

# %%
shu = pd.read_csv('datasets/PRSA_Data_Shunyi_20130301-20170228.csv')

# %%
wan = pd.read_csv('datasets/PRSA_Data_Wanliu_20130301-20170228.csv')

# %%
wans = pd.read_csv('datasets/PRSA_Data_Wanshouxigong_20130301-20170228.csv')

# %%
dfs = [aot, chan, ding, dong, guan, guch, hua, nong, shu, tian, wan, wans]

# %%
air = pd.concat(dfs)

# %%
air.reset_index(drop=True, inplace=True)

# %%
air.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
air.tail()
# Out:
#            No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 420763  35060  2017      2   28    19   11.0  32.0  3.0  24.0  400.0  72.0
# 420764  35061  2017      2   28    20   13.0  32.0  3.0  41.0  500.0  50.0
# 420765  35062  2017      2   28    21   14.0  28.0  4.0  38.0  500.0  54.0
# 420766  35063  2017      2   28    22   12.0  23.0  4.0  30.0  400.0  59.0
# 420767  35064  2017      2   28    23   13.0  19.0  4.0  38.0  600.0  49.0
#
#         TEMP    PRES  DEWP  RAIN   wd  WSPM        station
# 420763  12.5  1013.5 -16.2   0.0   NW   2.4  Wanshouxigong
# 420764  11.6  1013.6 -15.1   0.0  WNW   0.9  Wanshouxigong
# 420765  10.8  1014.2 -13.3   0.0   NW   1.1  Wanshouxigong
# 420766  10.5  1014.4 -12.9   0.0  NNW   1.2  Wanshouxigong
# 420767   8.6  1014.1 -15.9   0.0  NNE   1.3  Wanshouxigong

# %%
air.describe()
# Out:
#                   No           year          month            day  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.116943       1.177198       3.448707       8.800102
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  420768.000000  412029.000000  414319.000000  411747.000000
# mean       11.500000      79.793428     104.602618      15.830835
# std         6.922195      80.822391      91.772426      21.650603
# min         0.000000       2.000000       2.000000       0.285600
# ...

# %%
air = air.drop(columns='No', axis=1)

# %%
air.rename(columns= {'PM2.5' : 'PM25'}, inplace=True, index= str)

# %%
air.isnull().sum()
# Out:
# year           0
# month          0
# day            0
# hour           0
# PM25        8739
# PM10        6449
# SO2         9021
# NO2        12116
# CO         20701
# O3         13277
# TEMP         398
# PRES         393
# DEWP         403
# RAIN         390
# wd          1822
# WSPM         318
# station        0
# dtype: int64

# %%
round(air.isnull().sum() / len(air.index), 4) * 100
# Out:
# year       0.00
# month      0.00
# day        0.00
# hour       0.00
# PM25       2.08
# PM10       1.53
# SO2        2.14
# NO2        2.88
# CO         4.92
# O3         3.16
# TEMP       0.09
# PRES       0.09
# DEWP       0.10
# RAIN       0.09
# wd         0.43
# WSPM       0.08
# station    0.00
# dtype: float64

# %%
air.head()
# Out:
#    year  month  day  hour  PM25  PM10   SO2   NO2     CO    O3  TEMP    PRES  \
# 0  2013      3    1     0   4.0   4.0   4.0   7.0  300.0  77.0  -0.7  1023.0
# 1  2013      3    1     1   8.0   8.0   4.0   7.0  300.0  77.0  -1.1  1023.2
# 2  2013      3    1     2   7.0   7.0   5.0  10.0  300.0  73.0  -1.1  1023.5
# 3  2013      3    1     3   6.0   6.0  11.0  11.0  300.0  72.0  -1.4  1024.5
# 4  2013      3    1     4   3.0   3.0  12.0  12.0  300.0  72.0  -2.0  1025.2
#
#    DEWP  RAIN   wd  WSPM       station
# 0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1 -18.2   0.0    N   4.7  Aotizhongxin
# 2 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3 -19.4   0.0   NW   3.1  Aotizhongxin
# 4 -19.5   0.0    N   2.0  Aotizhongxin

# %%
pm25 = sns.boxplot(air['PM25'])
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pm25 = air.loc[air.PM25 >= 250]
pm25.head()
# Out:
#      year  month  day  hour   PM25   PM10    SO2    NO2      CO    O3  TEMP  \
# 120  2013      3    6     0  284.0  315.0  133.0  174.0  4000.0  28.0   4.9
# 121  2013      3    6     1  272.0  300.0  131.0  166.0  4000.0  22.0   4.8
# 140  2013      3    6    20  254.0  396.0  107.0  154.0  4200.0  17.0   4.4
# 141  2013      3    6    21  266.0  380.0  117.0  159.0  3799.0  17.0   3.8
# 142  2013      3    6    22  254.0  335.0  111.0  148.0  4099.0  17.0   2.4
#
#        PRES  DEWP  RAIN   wd  WSPM       station
# 120  1008.5  -6.4   0.0   NE   1.2  Aotizhongxin
# 121  1008.3  -5.9   0.0   NE   1.5  Aotizhongxin
# 140  1008.2  -2.5   0.0  SSW   1.1  Aotizhongxin
# 141  1007.7  -2.2   0.0  WSW   1.9  Aotizhongxin
# 142  1007.3  -2.5   0.0  WSW   1.2  Aotizhongxin

# %%
pm25.station.unique()
# Out:
# array(['Aotizhongxin', 'Changping', 'Dingling', 'Dongsi', 'Guanyuan',
#        'Gucheng', 'Huairou', 'Nongzhanguan', 'Shunyi', 'Tiantan',
#        'Wanliu', 'Wanshouxigong'], dtype=object)

# %%
pm10 = sns.boxplot(air.PM10)
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pm10 = air.loc[air.PM10 >= 320]
pm10.head()
# Out:
#      year  month  day  hour   PM25   PM10    SO2    NO2      CO    O3  TEMP  \
# 139  2013      3    6    19  242.0  338.0  124.0  164.0  3700.0  17.0   5.1
# 140  2013      3    6    20  254.0  396.0  107.0  154.0  4200.0  17.0   4.4
# 141  2013      3    6    21  266.0  380.0  117.0  159.0  3799.0  17.0   3.8
# 142  2013      3    6    22  254.0  335.0  111.0  148.0  4099.0  17.0   2.4
# 143  2013      3    6    23  260.0  360.0  119.0  145.0  4000.0  17.0   2.3
#
#        PRES  DEWP  RAIN   wd  WSPM       station
# 139  1007.6  -2.5   0.0  WSW   1.2  Aotizhongxin
# 140  1008.2  -2.5   0.0  SSW   1.1  Aotizhongxin
# 141  1007.7  -2.2   0.0  WSW   1.9  Aotizhongxin
# 142  1007.3  -2.5   0.0  WSW   1.2  Aotizhongxin
# 143  1007.2  -2.4   0.0  NNE   1.3  Aotizhongxin

# %%
((air['PM25'] >= 250) & (air['PM10'] >= 320)).sum()
# Out:
# 10047

# %%
air.describe()
# Out:
#                 year          month            day           hour  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean     2014.662560       6.522930      15.729637      11.500000
# std         1.177198       3.448707       8.800102       6.922195
# min      2013.000000       1.000000       1.000000       0.000000
# 25%      2014.000000       4.000000       8.000000       5.750000
# 50%      2015.000000       7.000000      16.000000      11.500000
# 75%      2016.000000      10.000000      23.000000      17.250000
# max      2017.000000      12.000000      31.000000      23.000000
#
#                 PM25           PM10            SO2            NO2  \
# count  412029.000000  414319.000000  411747.000000  408652.000000
# mean       79.793428     104.602618      15.830835      50.638586
# std        80.822391      91.772426      21.650603      35.127912
# min         2.000000       2.000000       0.285600       1.026500
# ...

# %%
so2 = sns.boxplot(air.SO2)
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
(air['SO2'] >= 70).sum()
# Out:
# 14571

# %%
((air.PM25 >= 250) & (air.PM10 >= 320) & (air.SO2 >= 70)).sum()
# Out:
# 2297

# %%
co2 = sns.boxplot(air.CO)
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
(air.CO >= 3000).sum()
# Out:
# 30355

# %%
o3 = sns.boxplot(air.O3)
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
(air.O3 >= 200).sum()
# Out:
# 13358

# %%
(air.O3 >= 470).sum()
# Out:
# 24

# %%
rain = sns.boxplot(air.RAIN)
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
color = ['windows blue', 'amber', 'faded green', 'dusty purple']
sns.set(rc= { "figure.figsize": (20, 10), 'axes.titlesize': 18, 'axes.labelsize': 12, 'xtick.labelsize': 14, 'ytick.labelsize': 14 })

# %%
sns.boxplot(x='station', y='PM25', data=air.dropna(axis=0))
# Out:
# <AxesSubplot:xlabel='station', ylabel='PM25'>

# %%
sns.boxplot(x='station', y='PM10', data=air.dropna(axis=0))
# Out:
# <AxesSubplot:xlabel='station', ylabel='PM10'>

# %%
sns.boxplot(x='station', y='SO2', data=air.dropna(axis=0))
# Out:
# <AxesSubplot:xlabel='station', ylabel='SO2'>

# %%
sns.boxplot(x='station', y='NO2', data=air.dropna(axis=0))
# Out:
# <AxesSubplot:xlabel='station', ylabel='NO2'>

# %%
sns.boxplot(x='station', y='CO', data=air.dropna(axis=0))
# Out:
# <AxesSubplot:xlabel='station', ylabel='CO'>

# %%
sns.boxplot(x='station', y='O3', data=air.dropna(axis=0))
# Out:
# <AxesSubplot:xlabel='station', ylabel='O3'>

# %%
sns.boxplot(x='station', y='RAIN', data=air.dropna(axis=0))
# Out:
# <AxesSubplot:xlabel='station', ylabel='RAIN'>

# %%
#Dealing with missing values
new_air = air

# %%
new_air.isnull().sum()
# Out:
# year           0
# month          0
# day            0
# hour           0
# PM25        8739
# PM10        6449
# SO2         9021
# NO2        12116
# CO         20701
# O3         13277
# TEMP         398
# PRES         393
# DEWP         403
# RAIN         390
# wd          1822
# WSPM         318
# station        0
# dtype: int64

# %%
#replacing missing values with median 
new_air['PM25'].fillna(new_air['PM25'].median(), inplace=True)

# %%
new_air['PM10'].fillna(new_air['PM10'].median(), inplace=True)

# %%
new_air['SO2'].fillna(new_air['SO2'].median(), inplace=True)
new_air['NO2'].fillna(new_air['NO2'].median(), inplace=True)
new_air['CO'].fillna(new_air['CO'].median(), inplace=True)
new_air['O3'].fillna(new_air['O3'].median(), inplace=True)
new_air['TEMP'].fillna(new_air['TEMP'].median(), inplace=True)
new_air['PRES'].fillna(new_air['PRES'].median(), inplace=True)
new_air['DEWP'].fillna(new_air['DEWP'].median(), inplace=True)
new_air['RAIN'].fillna(new_air['RAIN'].median(), inplace=True)
new_air['WSPM'].fillna(new_air['WSPM'].median(), inplace=True)

# %%
new_air.isnull().sum()
# Out:
# year          0
# month         0
# day           0
# hour          0
# PM25          0
# PM10          0
# SO2           0
# NO2           0
# CO            0
# O3            0
# TEMP          0
# PRES          0
# DEWP          0
# RAIN          0
# wd         1822
# WSPM          0
# station       0
# dtype: int64

# %%
#since wd is categorical so we use mode replacement
new_air = new_air.fillna(new_air['wd'].value_counts().index[0])

# %%
new_air.isnull().sum()
# Out:
# year       0
# month      0
# day        0
# hour       0
# PM25       0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
year_pm25 = new_air[['PM25', 'year', 'station']].groupby(['year']).median().reset_index().sort_values(by='year', ascending=False)

# %%
year_pm25
# Out:
#    year  PM25
# 4  2017  48.0
# 3  2016  50.0
# 2  2015  54.0
# 1  2014  60.0
# 0  2013  58.0

# %%
sns.pointplot(x='year', y='PM25', data=year_pm25)
# Out:
# <AxesSubplot:xlabel='year', ylabel='PM25'>

# %%
year_pm10 = new_air[['PM10', 'year', 'station']].groupby('year', as_index=False).median().sort_values('year', ascending=False)
year_pm10
# Out:
#    year  PM10
# 4  2017  71.0
# 3  2016  74.0
# 2  2015  79.0
# 1  2014  93.0
# 0  2013  86.0

# %%
sns.pointplot(data=year_pm10, x='year', y='PM10')
# Out:
# <AxesSubplot:xlabel='year', ylabel='PM10'>

# %%
year_so2 = new_air[['year', 'SO2', 'station']].groupby('year', as_index=False).median().sort_values('year', ascending=False)
year_so2
# Out:
#    year      SO2
# 4  2017  12.0000
# 3  2016   4.0000
# 2  2015   6.0000
# 1  2014   9.0000
# 0  2013  10.8528

# %%
sns.pointplot(data=year_so2, x='year', y='SO2')
# Out:
# <AxesSubplot:xlabel='year', ylabel='SO2'>

# %%
year_no2 = new_air[['year', 'NO2', 'station']].groupby('year', as_index=False).median().sort_values('year', ascending=False)
year_no2
# Out:
#    year   NO2
# 4  2017  50.0
# 3  2016  39.0
# 2  2015  41.0
# 1  2014  45.0
# 0  2013  46.0

# %%
sns.pointplot(data=year_no2, x='year', y='NO2')
# Out:
# <AxesSubplot:xlabel='year', ylabel='NO2'>

# %%
year_co = new_air[['year', 'CO', 'station']].groupby('year', as_index=False).median().sort_values('year', ascending=False)
year_co
# Out:
#    year     CO
# 4  2017  900.0
# 3  2016  800.0
# 2  2015  900.0
# 1  2014  900.0
# 0  2013  900.0

# %%
sns.pointplot(data=year_co, x='year', y='CO')
# Out:
# <AxesSubplot:xlabel='year', ylabel='CO'>

# %%
year_o3 = new_air[['year', 'O3', 'station']].groupby('year', as_index=False).median().sort_values('year', ascending=False)
year_o3
# Out:
#    year    O3
# 4  2017  38.0
# 3  2016  45.0
# 2  2015  45.0
# 1  2014  45.0
# 0  2013  45.0

# %%
sns.pointplot(data=year_o3, x='year', y='O3')
# Out:
# <AxesSubplot:xlabel='year', ylabel='O3'>

# %%
month_PM25 = new_air[['month', 'PM25', 'station']].groupby('month').median().reset_index().sort_values('month', ascending=False)
month_PM25
# Out:
#     month  PM25
# 11     12  55.0
# 10     11  64.0
# 9      10  55.0
# 8       9  48.0
# 7       8  42.0
# 6       7  57.0
# 5       6  54.0
# 4       5  52.0
# 3       4  59.0
# 2       3  69.0
# 1       2  48.0
# 0       1  60.0

# %%
sns.pointplot(data=month_PM25, x='month', y='PM25')
# Out:
# <AxesSubplot:xlabel='month', ylabel='PM25'>

# %%
month_PM10 = new_air[['month', 'PM10', 'station']].groupby('month').median().reset_index().sort_values('month', ascending=False)
month_PM10
# Out:
#     month    PM10
# 11     12   82.00
# 10     11   87.00
# 9      10   83.00
# 8       9   70.00
# 7       8   61.00
# 6       7   77.00
# 5       6   76.00
# 4       5   91.75
# 3       4  104.00
# 2       3  116.00
# 1       2   66.00
# 0       1   84.00

# %%
sns.pointplot(data=month_PM10, x='month', y='PM10')
# Out:
# <AxesSubplot:xlabel='month', ylabel='PM10'>

# %%
month_so2 = new_air[['month', 'SO2', 'station']].groupby('month').median().reset_index().sort_values('month', ascending=False)
month_so2
# Out:
#     month   SO2
# 11     12  18.0
# 10     11   9.0
# 9      10   4.0
# 8       9   3.0
# 7       8   3.0
# 6       7   3.0
# 5       6   4.0
# 4       5   7.0
# 3       4   9.0
# 2       3  18.0
# 1       2  15.0
# 0       1  21.0

# %%
sns.pointplot(data=month_so2, x='month', y='SO2')
# Out:
# <AxesSubplot:xlabel='month', ylabel='SO2'>

# %%
month_no2 = new_air[['month', 'NO2', 'station']].groupby('month').median().reset_index().sort_values('month', ascending=False)
month_no2
# Out:
#     month   NO2
# 11     12  62.0
# 10     11  58.0
# 9      10  54.0
# 8       9  42.0
# 7       8  31.0
# 6       7  32.0
# 5       6  35.0
# 4       5  37.0
# 3       4  43.0
# 2       3  55.0
# 1       2  43.0
# 0       1  58.0

# %%
sns.pointplot(data=month_no2, x='month', y='NO2')
# Out:
# <AxesSubplot:xlabel='month', ylabel='NO2'>

# %%
month_o3 = new_air[['month', 'O3', 'station']].groupby('month').median().reset_index().sort_values('month', ascending=False)
month_o3
# Out:
#     month    O3
# 11     12  13.0
# 10     11   9.0
# 9      10  19.0
# 8       9  45.0
# 7       8  72.0
# 6       7  76.0
# 5       6  80.0
# 4       5  80.0
# 3       4  68.0
# 2       3  50.0
# 1       2  42.0
# 0       1  21.0

# %%
sns.pointplot(data=month_o3, x='month', y='O3')
# Out:
# <AxesSubplot:xlabel='month', ylabel='O3'>

# %%
month_co = new_air[['month', 'CO', 'station']].groupby('month').median().reset_index().sort_values('month', ascending=False)
month_co
# Out:
#     month      CO
# 11     12  1200.0
# 10     11  1300.0
# 9      10   900.0
# 8       9   800.0
# 7       8   800.0
# 6       7   900.0
# 5       6   800.0
# 4       5   700.0
# 3       4   700.0
# 2       3  1000.0
# 1       2   900.0
# 0       1  1300.0

# %%
sns.pointplot(data=month_co, x='month', y='CO')
# Out:
# <AxesSubplot:xlabel='month', ylabel='CO'>

# %%
#heatmap correlation
import numpy as np
corr = new_air.corr()

# %%
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# %%
sns.heatmap(corr, annot=True, fmt='.2f', mask=mask)
plt.xticks(range(len(corr.columns)), corr.columns)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.show()
